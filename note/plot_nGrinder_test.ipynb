# %%
# vuser = 1000, N = 10,000
# Output
import numpy as np
import random
import time
import matplotlib.pyplot as plt
import pandas as pd

# df 생성
df_python_1000 = pd.read_csv("output_test_python_1000_7m_10^4.csv")
df_numpy_1000 = pd.read_csv("output_test_numpy_1000_7m_10^4.csv")

# DateTime 열을 datetime 형식으로 변환
# x축: 시간 (DateTime)
x1 = pd.to_datetime(df_python_1000["DateTime"])
x2 = pd.to_datetime(df_numpy_1000["DateTime"])

# y축 데이터
y1_python = df_python_1000["Mean_Test_Time_(ms)"]
y2_python = df_python_1000["TPS"]

y1_numpy = df_numpy_1000["Mean_Test_Time_(ms)"]
y2_numpy = df_numpy_1000["TPS"]

# 전체 그래프 크기 설정
plt.figure(figsize=(14, 6))

# 첫 번째 그래프 (Python)
plt.subplot(1, 2, 1)  # 1행 2열 중 첫 번째
plt.plot(x1, y1_python, color="blue", label="Mean_Test_Time(ms)")
plt.plot(x1, y2_python, color="red", label="TPS")
plt.xlabel("Time (DateTime)")
#plt.ylabel("")
plt.title("Python (1000vuser / no cache / N=10,000)")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)

# 두 번째 그래프 (NumPy)
plt.subplot(1, 2, 2)  # 1행 2열 중 두 번째
plt.plot(x2, y1_numpy, color="blue", label="Mean_Test_Time(ms)")
plt.plot(x2, y2_numpy, color="red", label="TPS")
plt.xlabel("Time (DateTime)")
#plt.ylabel("")
plt.title("Numpy (1000vuser / no cache / N=10,000)")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)

# 그래프 출력
plt.tight_layout()  # 그래프 간격 자동 조정
plt.show()

# %%
# vuser = 700, N = 10,000
# Output
import numpy as np
import random
import time
import matplotlib.pyplot as plt
import pandas as pd

# df 생성
df_python_700 = pd.read_csv("output_test_python_700_7m_10^4.csv")
df_numpy_700 = pd.read_csv("output_test_numpy_700_7m_10^4.csv")

# DateTime 열을 datetime 형식으로 변환
# x축: 시간 (DateTime)
x1 = pd.to_datetime(df_python_700["DateTime"])
x2 = pd.to_datetime(df_numpy_700["DateTime"])

# y축 데이터
y1_python = df_python_700["Mean_Test_Time_(ms)"]
y2_python = df_python_700["TPS"]

y1_numpy = df_numpy_700["Mean_Test_Time_(ms)"]
y2_numpy = df_numpy_700["TPS"]

# 전체 그래프 크기 설정
plt.figure(figsize=(14, 6))

# 첫 번째 그래프 (Python)
plt.subplot(1, 2, 1)  # 1행 2열 중 첫 번째
plt.plot(x1, y1_python, color="blue", label="Mean_Test_Time(ms)")
plt.plot(x1, y2_python, color="red", label="TPS")
plt.xlabel("Time (DateTime)")
#plt.ylabel("")
plt.title("Python (700vuser / no cache / N=10,000)")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)

# 두 번째 그래프 (NumPy)
plt.subplot(1, 2, 2)  # 1행 2열 중 두 번째
plt.plot(x2, y1_numpy, color="blue", label="Mean_Test_Time(ms)")
plt.plot(x2, y2_numpy, color="red", label="TPS")
plt.xlabel("Time (DateTime)")
#plt.ylabel("")
plt.title("Numpy (700vuser / no cache / N=10,000)")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)

# 그래프 출력
plt.tight_layout()  # 그래프 간격 자동 조정
plt.show()

# %%
# vuser = 1000, N = 100,000
# Output
import numpy as np
import random
import time
import matplotlib.pyplot as plt
import pandas as pd

# df 생성
df_python_1000 = pd.read_csv("output_test_python_1000_7m_10^5.csv")
df_numpy_1000 = pd.read_csv("output_test_numpy_1000_7m_10^5.csv")

# DateTime 열을 datetime 형식으로 변환
# x축: 시간 (DateTime)
x1 = pd.to_datetime(df_python_1000["DateTime"])
x2 = pd.to_datetime(df_numpy_1000["DateTime"])

# y축 데이터
y1_python = df_python_1000["Mean_Test_Time_(ms)"]
y2_python = df_python_1000["TPS"]

y1_numpy = df_numpy_1000["Mean_Test_Time_(ms)"]
y2_numpy = df_numpy_1000["TPS"]

# 전체 그래프 크기 설정
plt.figure(figsize=(14, 6))

# 첫 번째 그래프 (Python)
plt.subplot(1, 2, 1)  # 1행 2열 중 첫 번째
plt.plot(x1, y1_python, color="blue", label="Mean_Test_Time(ms)")
plt.plot(x1, y2_python, color="red", label="TPS")
plt.xlabel("Time (DateTime)")
#plt.ylabel("")
plt.title("Python (1000vuser / no cache / N=100,000)")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)

# 두 번째 그래프 (NumPy)
plt.subplot(1, 2, 2)  # 1행 2열 중 두 번째
plt.plot(x2, y1_numpy, color="blue", label="Mean_Test_Time(ms)")
plt.plot(x2, y2_numpy, color="red", label="TPS")
plt.xlabel("Time (DateTime)")
#plt.ylabel("")
plt.title("Numpy (1000vuser / no cache / N=100,000)")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)

# 그래프 출력
plt.tight_layout()  # 그래프 간격 자동 조정
plt.show()

# %%
# vuser = 700, N = 100,000
# Output
import numpy as np
import random
import time
import matplotlib.pyplot as plt
import pandas as pd

# df 생성
df_python_700 = pd.read_csv("output_test_python_700_7m_10^5.csv")
df_numpy_700 = pd.read_csv("output_test_numpy_700_7m_10^5.csv")

# DateTime 열을 datetime 형식으로 변환
# x축: 시간 (DateTime)
x1 = pd.to_datetime(df_python_700["DateTime"])
x2 = pd.to_datetime(df_numpy_700["DateTime"])

# y축 데이터
y1_python = df_python_700["Mean_Test_Time_(ms)"]
y2_python = df_python_700["TPS"]

y1_numpy = df_numpy_700["Mean_Test_Time_(ms)"]
y2_numpy = df_numpy_700["TPS"]

# 전체 그래프 크기 설정
plt.figure(figsize=(14, 6))

# 첫 번째 그래프 (Python)
plt.subplot(1, 2, 1)  # 1행 2열 중 첫 번째
plt.plot(x1, y1_python, color="blue", label="Mean_Test_Time(ms)")
plt.plot(x1, y2_python, color="red", label="TPS")
plt.xlabel("Time (DateTime)")
#plt.ylabel("")
plt.title("Python (700vuser / no cache / N=100,000)")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)

# 두 번째 그래프 (NumPy)
plt.subplot(1, 2, 2)  # 1행 2열 중 두 번째
plt.plot(x2, y1_numpy, color="blue", label="Mean_Test_Time(ms)")
plt.plot(x2, y2_numpy, color="red", label="TPS")
plt.xlabel("Time (DateTime)")
#plt.ylabel("")
plt.title("Numpy (700vuser / no cache / N=100,000)")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)

# 그래프 출력
plt.tight_layout()  # 그래프 간격 자동 조정
plt.show()

# %%
# vuser = 1000, N = 10,000
# Docker Stats
import numpy as np
import random
import time
import matplotlib.pyplot as plt
import pandas as pd


def filter_dataframe_stats_python_1000(file_path_stats_python_1000):
    """
    CSV 파일에서 'Name' 열의 값이 'reverse-proxy-api-1'인 행만 추출하여 데이터프레임을 반환합니다.

    Args:
        file_path (str): CSV 파일 경로

    Returns:
        pandas.DataFrame: 필터링된 데이터프레임
    """
    try:
        # CSV 파일 읽기
        df_stats_python_1000 = pd.read_csv(file_path_stats_python_1000)

        # 'ID' 열의 값이 'reverse-proxy-api-1'인 행만 추출
        filtered_df_stats_python_1000 = df_stats_python_1000[df_stats_python_1000['Name'] == 'reverse-proxy-api-1']

        return filtered_df_stats_python_1000

    except FileNotFoundError:
        print(f"오류: 파일을 찾을 수 없습니다. {file_path_stats_python_1000}")
        return None
    except Exception as e:
        print(f"오류: {e}")
        return None

# 사용 예시
file_path_stats_python_1000 = "docker_stats_test_python_1000_7m_10^4.csv"  # CSV 파일 경로
filtered_df_stats_python_1000 = filter_dataframe_stats_python_1000(file_path_stats_python_1000)

def filter_dataframe_stats_numpy_1000(file_path_stats_nummpy_1000):
    """
    CSV 파일에서 'Name' 열의 값이 'reverse-proxy-api-1'인 행만 추출하여 데이터프레임을 반환합니다.

    Args:
        file_path (str): CSV 파일 경로

    Returns:
        pandas.DataFrame: 필터링된 데이터프레임
    """
    try:
        # CSV 파일 읽기
        df_stats_numpy_1000 = pd.read_csv(file_path_stats_numpy_1000)

        # 'ID' 열의 값이 'reverse-proxy-api-1'인 행만 추출
        filtered_df_stats_numpy_1000 = df_stats_numpy_1000[df_stats_numpy_1000['Name'] == 'reverse-proxy-api-1']

        return filtered_df_stats_numpy_1000

    except FileNotFoundError:
        print(f"오류: 파일을 찾을 수 없습니다. {file_path_stats_numpy_1000}")
        return None
    except Exception as e:
        print(f"오류: {e}")
        return None

# 사용 예시
file_path_stats_numpy_1000 = "docker_stats_test_numpy_1000_7m_10^4.csv"  # CSV 파일 경로
filtered_df_stats_numpy_1000 = filter_dataframe_stats_numpy_1000(file_path_stats_numpy_1000)


# df 생성
#df_python_stats_1000 = pd.read_csv("docker_stats_test_python_1000_7m_10*4.csv")
#df_numpy_stats_1000 = pd.read_csv("docker_stats_test_numpy_1000_7m_10^4.csv")


if filtered_df_stats_python_1000 is not None and filtered_df_stats_numpy_1000 is not None:
    # DateTime 열을 datetime 형식으로 변환
    x1_stats = pd.to_datetime(filtered_df_stats_python_1000["Timestamp"], unit='s')
    filtered_df_stats_python_1000['Timestamp'] = pd.to_datetime(filtered_df_stats_python_1000['Timestamp'], unit='s').dt.tz_localize('UTC').dt.tz_convert('Asia/Seoul')
    #x2_stats = pd.to_datetime(filtered_df_stats_numpy_1000["Timestamp"], unit='s')
    #filtered_df_stats_numpy_1000['Timestamp'] = pd.to_datetime(filtered_df_stats_numpy_1000['Timestamp'], unit='s').dt.tz_localize('UTC').dt.tz_convert('Asia/Seoul')

    # y축 데이터
    y1_stats_python = filtered_df_stats_python_1000["CPUPerc"].str.rstrip('%').astype(float)
    y2_stats_python = filtered_df_stats_python_1000["MemPerc"].str.rstrip('%').astype(float)

    #y1_stats_numpy = filtered_df_stats_numpy_1000["CPUPerc"].str.rstrip('%').astype(float)
    #y2_stats_numpy = filtered_df_stats_numpy_1000["MemPerc"].str.rstrip('%').astype(float)

    # 전체 그래프 크기 설정
    plt.figure(figsize=(14, 6))

    # 첫 번째 그래프 (Python)
    plt.subplot(1, 2, 1) # 1행 2열 중 첫 번째
    plt.plot(x1_stats, y1_stats_python, color="blue", label="CPUPerc")
    #plt.plot(x1_stats, y2_stats_python, color="red", label="MemPerc")
    plt.xlabel("Time (DateTime)")
    plt.title("Python CPU% (1,000vuser / no cache / N=10,000)")
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)

    # 두 번째 그래프 (NumPy)
    plt.subplot(1, 2, 2) # 1행 2열 중 두 번째
    plt.plot(x1_stats, y2_stats_python, color="red", label="MemPerc")
    #plt.plot(x2_stats, y1_stats_numpy, color="blue", label="CPUPerc")
    #plt.plot(x2_stats, y2_stats_numpy, color="red", label="MemPerc")
    plt.xlabel("Time (DateTime)")
    plt.title("Python Mem% (1,000vuser / no cache / N=10,000)")
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)

    # 그래프 출력
    plt.tight_layout() # 그래프 간격 자동 조정
    plt.show()
else:
    print("오류: 데이터프레임 필터링 실패. 파일 경로 및 데이터를 확인하십시오.")

# %%
# vuser = 1000, N = 10,000
# Docker Stats
import numpy as np
import random
import time
import matplotlib.pyplot as plt
import pandas as pd


def filter_dataframe_stats_python_1000(file_path_stats_python_1000):
    """
    CSV 파일에서 'Name' 열의 값이 'reverse-proxy-api-1'인 행만 추출하여 데이터프레임을 반환합니다.

    Args:
        file_path (str): CSV 파일 경로

    Returns:
        pandas.DataFrame: 필터링된 데이터프레임
    """
    try:
        # CSV 파일 읽기
        df_stats_python_1000 = pd.read_csv(file_path_stats_python_1000)

        # 'ID' 열의 값이 'reverse-proxy-api-1'인 행만 추출
        filtered_df_stats_python_1000 = df_stats_python_1000[df_stats_python_1000['Name'] == 'reverse-proxy-api-1']

        return filtered_df_stats_python_1000

    except FileNotFoundError:
        print(f"오류: 파일을 찾을 수 없습니다. {file_path_stats_python_1000}")
        return None
    except Exception as e:
        print(f"오류: {e}")
        return None

# 사용 예시
file_path_stats_python_1000 = "docker_stats_test_python_1000_7m_10^4.csv"  # CSV 파일 경로
filtered_df_stats_python_1000 = filter_dataframe_stats_python_1000(file_path_stats_python_1000)

def filter_dataframe_stats_numpy_1000(file_path_stats_nummpy_1000):
    """
    CSV 파일에서 'Name' 열의 값이 'reverse-proxy-api-1'인 행만 추출하여 데이터프레임을 반환합니다.

    Args:
        file_path (str): CSV 파일 경로

    Returns:
        pandas.DataFrame: 필터링된 데이터프레임
    """
    try:
        # CSV 파일 읽기
        df_stats_numpy_1000 = pd.read_csv(file_path_stats_numpy_1000)

        # 'ID' 열의 값이 'reverse-proxy-api-1'인 행만 추출
        filtered_df_stats_numpy_1000 = df_stats_numpy_1000[df_stats_numpy_1000['Name'] == 'reverse-proxy-api-1']

        return filtered_df_stats_numpy_1000

    except FileNotFoundError:
        print(f"오류: 파일을 찾을 수 없습니다. {file_path_stats_numpy_1000}")
        return None
    except Exception as e:
        print(f"오류: {e}")
        return None

# 사용 예시
file_path_stats_numpy_1000 = "docker_stats_test_numpy_1000_7m_10^4.csv"  # CSV 파일 경로
filtered_df_stats_numpy_1000 = filter_dataframe_stats_numpy_1000(file_path_stats_numpy_1000)


# df 생성
#df_python_stats_1000 = pd.read_csv("docker_stats_test_python_1000_7m_10*4.csv")
#df_numpy_stats_1000 = pd.read_csv("docker_stats_test_numpy_1000_7m_10^4.csv")


if filtered_df_stats_python_1000 is not None and filtered_df_stats_numpy_1000 is not None:
    # DateTime 열을 datetime 형식으로 변환
    #x1_stats = pd.to_datetime(filtered_df_stats_python_1000["Timestamp"], unit='s')
    #filtered_df_stats_python_1000['Timestamp'] = pd.to_datetime(filtered_df_stats_python_1000['Timestamp'], unit='s').dt.tz_localize('UTC').dt.tz_convert('Asia/Seoul')
    x2_stats = pd.to_datetime(filtered_df_stats_numpy_1000["Timestamp"], unit='s')
    filtered_df_stats_numpy_1000['Timestamp'] = pd.to_datetime(filtered_df_stats_numpy_1000['Timestamp'], unit='s').dt.tz_localize('UTC').dt.tz_convert('Asia/Seoul')

    # y축 데이터
    #y1_stats_python = filtered_df_stats_python_1000["CPUPerc"].str.rstrip('%').astype(float)
    #y2_stats_python = filtered_df_stats_python_1000["MemPerc"].str.rstrip('%').astype(float)

    y1_stats_numpy = filtered_df_stats_numpy_1000["CPUPerc"].str.rstrip('%').astype(float)
    y2_stats_numpy = filtered_df_stats_numpy_1000["MemPerc"].str.rstrip('%').astype(float)

    # 전체 그래프 크기 설정
    plt.figure(figsize=(14, 6))

    # 첫 번째 그래프 (Numpy_CPU)
    plt.subplot(1, 2, 1) # 1행 2열 중 첫 번째
    #plt.plot(x1_stats, y1_stats_python, color="blue", label="CPUPerc")
    plt.plot(x2_stats, y1_stats_numpy, color="blue", label="CPUPerc")
    #plt.plot(x1_stats, y2_stats_python, color="red", label="MemPerc")
    plt.xlabel("Time (DateTime)")
    plt.title("Numpy CPU% (1,000vuser / no cache / N=10,000)")
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)

    # 두 번째 그래프 (Numpy_Mem)
    plt.subplot(1, 2, 2) # 1행 2열 중 두 번째
    #plt.plot(x2_stats, y1_stats_numpy, color="blue", label="CPUPerc")
    plt.plot(x2_stats, y2_stats_numpy, color="red", label="MemPerc")
    plt.xlabel("Time (DateTime)")
    plt.title("Numpy Mem% (1,000vuser / no cache / N=10,000)")
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)

    # 그래프 출력
    plt.tight_layout() # 그래프 간격 자동 조정
    plt.show()
else:
    print("오류: 데이터프레임 필터링 실패. 파일 경로 및 데이터를 확인하십시오.")

# %%
# vuser = 700, N = 10,000
# Docker Stats
import numpy as np
import random
import time
import matplotlib.pyplot as plt
import pandas as pd


def filter_dataframe_stats_python_700(file_path_stats_python_700):
    """
    CSV 파일에서 'Name' 열의 값이 'reverse-proxy-api-1'인 행만 추출하여 데이터프레임을 반환합니다.

    Args:
        file_path (str): CSV 파일 경로

    Returns:
        pandas.DataFrame: 필터링된 데이터프레임
    """
    try:
        # CSV 파일 읽기
        df_stats_python_700 = pd.read_csv(file_path_stats_python_700)

        # 'ID' 열의 값이 'reverse-proxy-api-1'인 행만 추출
        filtered_df_stats_python_700 = df_stats_python_700[df_stats_python_700['Name'] == 'reverse-proxy-api-1']

        return filtered_df_stats_python_700

    except FileNotFoundError:
        print(f"오류: 파일을 찾을 수 없습니다. {file_path_stats_python_700}")
        return None
    except Exception as e:
        print(f"오류: {e}")
        return None

# 사용 예시
file_path_stats_python_700 = "docker_stats_test_python_700_7m_10^4.csv"  # CSV 파일 경로
filtered_df_stats_python_700 = filter_dataframe_stats_python_700(file_path_stats_python_700)

def filter_dataframe_stats_numpy_700(file_path_stats_nummpy_700):
    """
    CSV 파일에서 'Name' 열의 값이 'reverse-proxy-api-1'인 행만 추출하여 데이터프레임을 반환합니다.

    Args:
        file_path (str): CSV 파일 경로

    Returns:
        pandas.DataFrame: 필터링된 데이터프레임
    """
    try:
        # CSV 파일 읽기
        df_stats_numpy_700 = pd.read_csv(file_path_stats_numpy_700)

        # 'ID' 열의 값이 'reverse-proxy-api-1'인 행만 추출
        filtered_df_stats_numpy_700 = df_stats_numpy_700[df_stats_numpy_700['Name'] == 'reverse-proxy-api-1']

        return filtered_df_stats_numpy_700

    except FileNotFoundError:
        print(f"오류: 파일을 찾을 수 없습니다. {file_path_stats_numpy_700}")
        return None
    except Exception as e:
        print(f"오류: {e}")
        return None

# 사용 예시
file_path_stats_numpy_700 = "docker_stats_test_numpy_700_7m_10^4.csv"  # CSV 파일 경로
filtered_df_stats_numpy_700 = filter_dataframe_stats_numpy_700(file_path_stats_numpy_700)


# df 생성
#df_python_stats_1000 = pd.read_csv("docker_stats_test_python_1000_7m_10*4.csv")
#df_numpy_stats_1000 = pd.read_csv("docker_stats_test_numpy_1000_7m_10^4.csv")


if filtered_df_stats_python_700 is not None and filtered_df_stats_numpy_700 is not None:
    # DateTime 열을 datetime 형식으로 변환
    #x1_stats = pd.to_datetime(filtered_df_stats_python_700["Timestamp"], unit='s')
    #filtered_df_stats_python_700['Timestamp'] = pd.to_datetime(filtered_df_stats_python_700['Timestamp'], unit='s').dt.tz_localize('UTC').dt.tz_convert('Asia/Seoul')
    x2_stats = pd.to_datetime(filtered_df_stats_numpy_700["Timestamp"], unit='s')
    filtered_df_stats_numpy_700['Timestamp'] = pd.to_datetime(filtered_df_stats_numpy_700['Timestamp'], unit='s').dt.tz_localize('UTC').dt.tz_convert('Asia/Seoul')

    # y축 데이터
    #y1_stats_python = filtered_df_stats_python_700["CPUPerc"].str.rstrip('%').astype(float)
    #y2_stats_python = filtered_df_stats_python_700["MemPerc"].str.rstrip('%').astype(float)

    y1_stats_numpy = filtered_df_stats_numpy_700["CPUPerc"].str.rstrip('%').astype(float)
    y2_stats_numpy = filtered_df_stats_numpy_700["MemPerc"].str.rstrip('%').astype(float)

    # 전체 그래프 크기 설정
    plt.figure(figsize=(14, 6))

    # 첫 번째 그래프 (Numpy_CPU)
    plt.subplot(1, 2, 1) # 1행 2열 중 첫 번째
    #plt.plot(x1_stats, y1_stats_python, color="blue", label="CPUPerc")
    plt.plot(x2_stats, y1_stats_numpy, color="blue", label="CPUPerc")
    #plt.plot(x1_stats, y2_stats_python, color="red", label="MemPerc")
    plt.xlabel("Time (DateTime)")
    plt.title("Numpy CPU% (700vuser / no cache / N=10,000)")
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)

    # 두 번째 그래프 (Numpy_Mem)
    plt.subplot(1, 2, 2) # 1행 2열 중 두 번째
    #plt.plot(x2_stats, y1_stats_numpy, color="blue", label="CPUPerc")
    plt.plot(x2_stats, y2_stats_numpy, color="red", label="MemPerc")
    plt.xlabel("Time (DateTime)")
    plt.title("Numpy Mem% (700vuser / no cache / N=10,000)")
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)

    # 그래프 출력
    plt.tight_layout() # 그래프 간격 자동 조정
    plt.show()
else:
    print("오류: 데이터프레임 필터링 실패. 파일 경로 및 데이터를 확인하십시오.")
# Out:
# 오류: name 'df_stats_python_1000' is not defined
# 오류: name 'df_stats_numpy_1000' is not defined
# 오류: 데이터프레임 필터링 실패. 파일 경로 및 데이터를 확인하십시오.
